# %% [markdown]
# # Tournament Model
# #### Using [previously defined models](drops.ipynb), we can create a tournament model that uses a weighted average of the models to aggregate a new ranking of the teams.

# %%
from src.tournament import Tournament
from src import Iqr, StdDeviation, SuperScoreModel, Mean

models = [(0.4, Iqr), (0.1, StdDeviation), (0.3, SuperScoreModel), (0.2, Mean)]

t_model = Tournament(
    path="../data/2023-02-18_penn_invitational_c.yaml", models_to_use=models
)

# %% [markdown]
#  Each tournament is assigned a `tourney_weight`, calculated based on the number of teams present that were also present at the national tournament the previous year * a recency multiplier.
#  #### ⚠️ This is a major area for improvement, as the current method of calculating the `tourney_weight` is not robust nor necessarily an accurate approach.

# %% [markdown]
# ##### Each team's `rel_score` is the sum of the $\sum (w_m \cdot r_t )$ for each model, where $w_m$ is the weight of the model and $r_t$ is the team's ranking in the model.
#
# This logic is implemented in the `aggregate` method of the `Tournament` class.

# %%
t_model.aggregate()

for i, (name, rel_score) in enumerate(sorted(t_model.prelim.items(), key=lambda x: x[1])):
    print(f"{i+1}: {name} - {rel_score}")
# Out:
# 1: Montgomery High School - 0.3
# 2: Adlai E. Stevenson High School - 0.6
# 3: West Windsor-Plainsboro High School North - 0.8999999999999999
# 4: West Windsor-Plainsboro High School South - 1.2
# 5: Ward Melville High School - 1.5
# 6: Harriton High School - 1.7999999999999998
# 7: William G. Enloe High School - 2.1
# 8: Great Neck South High School - 2.4
# 9: Syosset High School - 2.6999999999999997
# 10: Lower Merion High School - 3.0
# 11: Cumberland Valley High School - 3.3
# 12: Centennial High School - 3.5999999999999996
# 13: South Brunswick High School - 3.9
# 14: East Brunswick High School - 4.2
# 15: John Jay High School - 4.5
# 16: Chaminade High School - 4.8
# 17: Northridge High School - 5.1
# 18: Penncrest High School - 5.3999999999999995
# 19: Fairfax High School - 5.7
# 20: North Pocono High School - 6.0
# 21: Columbia High School - 6.3
# 22: Ed W. Clark High School - 6.6
# 23: Bayard Rustin High School - 6.8999999999999995
# 24: Garnet Valley High School - 7.199999999999999
# 25: Charter School of Wilmington - 7.5
# 26: North Penn High School - 7.8
# 27: Shipley School - 8.1
# 28: Cherry Hill High School East - 8.4
# 29: West Chester East High School - 8.7
# 30: Haverford High School - 9.0
# 31: Allentown Central Catholic High School - 9.299999999999999
# 32: Central High School - 9.6
# 33: JR Masterman School - 9.9
# 34: Parsippany High School - 10.2
# 35: Kingsway Regional High School - 10.5
# 36: Philadelphia High School for Girls - 10.799999999999999

# %% [markdown]
# ### Major Drawbacks
#
# This model fails to account for very competitive teams that may not have attended the national tournament the previous year. This is especially prevalent in competitive states such as California, where the state is limited to 2 bids to the national tournament. This issue can be approached through manually assigning `tourney_weight` values to tournaments, but this also is not a robust solution.
#
# ##### Another consideration is the actual results that should also be weighed in the final ranking. This is not currently implemented, but is a major area for improvement. # TODO

# %% [markdown]
# # Implementation of This Model
# This model is intended to be a representation of a tournament and should be used to model many tournaments and aggregate the results.
#
# ##### Example:

# %%
tournament_paths = [
    "../data/2022-11-19_palatine_invitational_c.yaml",
    "../data/2022-12-03_northview_invitational_c.yaml",
    "../data/2023-02-18_penn_invitational_c.yaml",
    "../data/2023-02-04_solon_invitational_c.yaml",
    "../data/2023-01-21_mit_invitational_c.yaml",
    "../data/2023-02-11_golden_gate_invitational_c.yaml",
    "../data/2022-12-03_boyceville_satellite_invitational_c.yaml"
]
team_d: dict[str, []] = {}
for path in tournament_paths:
    t_model = Tournament(path=path, models_to_use=models)
    t_model.aggregate()
    print(f"Results for {path}")
    teams = len(t_model.ranks)
    for i, name in enumerate(
        t_model.ranks
    ):
        if name not in team_d:
            team_d[name] = []
        team_d[name].append((1 - (i+1)/teams, t_model.tourney_weight))

final_rank = {}
for name, dlist in team_d.items():
    items = len(dlist)
    for i, (rel_score, tourney_weight) in enumerate(dlist):
        if name not in final_rank:
            final_rank[name] = 0
        final_rank[name] += (rel_score * tourney_weight)
    final_rank[name] * 100/items
        
            
            
for i, (name, rel_score) in enumerate(sorted(final_rank.items(), key=lambda x: x[1], reverse=True)):
    print(f"{i+1}: {name} - {rel_score}")
# Out:
# Results for ../data/2022-11-19_palatine_invitational_c.yaml
# Results for ../data/2022-12-03_northview_invitational_c.yaml
# Results for ../data/2023-02-18_penn_invitational_c.yaml
# Results for ../data/2023-02-04_solon_invitational_c.yaml
# Results for ../data/2023-01-21_mit_invitational_c.yaml
# Results for ../data/2023-02-11_golden_gate_invitational_c.yaml
# Results for ../data/2022-12-03_boyceville_satellite_invitational_c.yaml
# 1: Montgomery High School - 0.2485542272991666
# 2: West Windsor-Plainsboro High School North - 0.2480253664464191
# 3: Ward Melville High School - 0.24749717818441236
# 4: Adlai E. Stevenson High School - 0.23565245918343483
# 5: Harriton High School - 0.23393767725751533
# 6: New Trier High School - 0.22493379356152188
# 7: Troy High School - 0.22105240464145712
# 8: Mountain View High School - 0.21851754287078695
# 9: Syosset High School - 0.20987918963627467
# 10: Mason High School - 0.20676137869019615
# 11: William G. Enloe High School - 0.20043725205668528
# 12: Lower Merion High School - 0.19299676182267278
# 13: Marquette University High School - 0.1639980380243282
# 14: Ed W. Clark High School - 0.158595428924008
# 15: Cumberland Valley High School - 0.14475094041835235
# 16: Acton-Boxborough Regional High School - 0.14291477753016216
# 17: Seven Lakes High School - 0.13294397909782524
# 18: Liberal Arts and Science Academy - 0.12957802788820827
# 19: Fairfax High School - 0.12746849791384204
# 20: West Windsor-Plainsboro High School South - 0.11481695692222008
# 21: Stuyvesant High School - 0.10303158380081458
# 22: Great Neck South High School - 0.10046483730694257
# 23: South Brunswick High School - 0.10000635083912898
# 24: John Jay High School - 0.0978805492463054
# 25: Lexington High School - 0.09306078536847767
# 26: Chaminade High School - 0.09273859373792753
# 27: Solon High School - 0.09132696618345298
# 28: Iolani School - 0.0864135864135864
# 29: Centennial High School - 0.08611271769166508
# 30: Hillsborough High School - 0.08308998693614078
# 31: Boca Raton High School - 0.07976638745869515
# 32: East Brunswick High School - 0.07893665788402632
# 33: Pioneer High School - 0.07761698691664248
# 34: Orlando Science High School - 0.07644278798124952
# 35: Barrington High School - 0.07511456034807683
# 36: Glen A. Wilson High School - 0.07391927765874334
# 37: Westlake High School - 0.07109002746201369
# 38: Saline High School - 0.07019845825815976
# 39: Belmont High School - 0.06979558902635825
# 40: Northridge High School - 0.06817256817256817
# 41: Tesla STEM High School - 0.06623599174692696
# 42: Penncrest High School - 0.0645845382687488
# 43: Collegiate School - 0.06314839007146698
# 44: Milpitas High School - 0.057408847159435714
# 45: North Pocono High School - 0.05740847846111004
# 46: Winchester High School - 0.056501191116575734
# 47: International Academy Central - 0.05601746129874718
# 48: Mentor High School - 0.055781952452446146
# 49: Columbia High School - 0.05382044855729066
# 50: Centerville High School - 0.05347733017078597
# 51: Archimedean Upper Conservatory - 0.0531775916391301
# 52: duPont Manual High School - 0.05190446751870403
# 53: Olentangy Orange High School - 0.04993628644604535
# 54: Bronx High School of Science - 0.04985399216168447
# 55: Castro Valley High School - 0.04903488245806305
# 56: Lake Central High School - 0.04886311033289055
# 57: New Albany High School - 0.04875874221454015
# 58: Munster High School - 0.04836959883298039
# 59: Bayard Rustin High School - 0.04664438874965192
# 60: Wellesley High School - 0.04653039268423884
# 61: Temple City High School - 0.04597020230443411
# 62: Beachwood High School - 0.04561301691037627
# 63: Mission San Jose High School - 0.04443786222761964
# 64: Dublin High School - 0.043574615412617396
# 65: Westborough High School - 0.0432067932067932
# 66: Garnet Valley High School - 0.04305635884583254
# 67: Jordan High School - 0.042905522150805175
# 68: Mayfield High School - 0.04246729160621238
# 69: Irvington High School - 0.040488349731244405
# 70: Bedford High School - 0.03988319372934757
# 71: Charter School of Wilmington - 0.03946832894201316
# 72: Kenston High School - 0.039321566302048507
# 73: Palo Alto High School - 0.03830850192036176
# 74: American High School - 0.03677616184354729
# 75: Boston University Academy - 0.036559594251901945
# 76: Hudson High School - 0.03617584099788463
# 77: North Penn High School - 0.03588029903819378
# 78: Newton North High School - 0.033235994774456316
# 79: Shipley School - 0.0322922691343744
# 80: Canyon Crest Academy - 0.032179141613103875
# 81: Chardon High School - 0.0314572530416388
# 82: Monta Vista High School - 0.030646801536289407
# 83: Thomas Jefferson High School for Science and Technology - 0.030301549288891064
# 84: Jonathan Law High School - 0.029912395297010688
# 85: Hawken School - 0.02988439038955687
# 86: Diamond Bar High School - 0.029524586486611805
# 87: Mountain House High School - 0.029114461459474942
# 88: South Forsyth High School - 0.02874762368433255
# 89: Cherry Hill High School East - 0.02870423923055502
# 90: Saint Ignatius High School - 0.028311527737474928
# 91: BASIS Independent Silicon Valley - 0.027582121382660463
# 92: Brooklyn Technical High School - 0.027193698079774033
# 93: University High School - 0.026805216678634402
# 94: St. Edward High School - 0.026738665085392986
# 95: Sharon High School - 0.026588795819565043
# 96: Granville High School - 0.026107837818515205
# 97: Naperville North High School - 0.026082548403976974
# 98: Davidson Academy - 0.026049781305846
# 99: Brookwood High School - 0.026028253876355142
# 100: Athens High School - 0.02592279515356439
# 101: Northville High School - 0.02568728630726335
# 102: Governor Livingston High School - 0.025639772475215514
# 103: Scarsdale High School - 0.025251291074075883
# 104: Northmont High School - 0.025165802433311044
# 105: West Chester East High School - 0.02511620932673564
# 106: Okemos High School - 0.024795717103409415
# 107: Mira Loma High School - 0.024517441229031527
# 108: Walton High School - 0.02447432827179663
# 109: Thomas Worthington High School - 0.023828448627530148
# 110: West Michigan Aviation Academy - 0.023668639053254444
# 111: Boyceville High School - 0.023592939781229103
# 112: Neuqua Valley High School - 0.023384353741496597
# 113: Holt High School - 0.023308884068377743
# 114: Falmouth High School - 0.023265196342119415
# 115: Rancho Bernardo High School - 0.02292040266723811
# 116: Waubonsie Valley High School - 0.022484955520669807
# 117: Lambert High School - 0.022143439864958855
# 118: Medina High School - 0.02202007712914716
# 119: Fulton Science Academy - 0.021754958463819224
# 120: Naperville Central High School - 0.021585557299843013
# 121: Haverford High School - 0.021528179422916262
# 122: Bothell High School - 0.021366477062679592
# 123: Detroit Country Day Upper School - 0.02028740490278952
# 124: Northwood High School - 0.02020103285926071
# 125: Nashua High School North - 0.019941596864673786
# 126: Pleasant Grove High School - 0.019920420998588116
# 127: Staten Island Technical High School - 0.01981255145812108
# 128: Oak Park River Forest High School - 0.01978676085818943
# 129: East Lansing High School - 0.019424070056981452
# 130: Novi High School - 0.019160326852634545
# 131: Vernon Hills High School - 0.018887362637362636
# 132: Archbishop Hoban High School - 0.018874351824983284
# 133: River City Science Academy - 0.018647107254702193
# 134: Davis Senior High School - 0.018388080921773645
# 135: The Bronx High School of Science - 0.018258625853562565
# 136: Crystal Lake Central High School - 0.017987964416535843
# 137: Allentown Central Catholic High School - 0.017940149519096883
# 138: Westfield High School - 0.017870144452422933
# 139: Canal Winchester High School - 0.017301489172901342
# 140: Hudsonville High School - 0.01709318165014368
# 141: Hinsdale Central High School - 0.017088566195709053
# 142: Tokay High School - 0.016855740844959173
# 143: Lane Tech College Prep High School - 0.01670470024900405
# 144: Cambridge Rindge and Latin School - 0.016617997387228158
# 145: Fulton County Innovation Academy - 0.016316218847864418
# 146: Cary Grove High School - 0.01618916797488226
# 147: Plattsburgh High School - 0.01592773744672479
# 148: Cincinnati Country Day School - 0.01577909270216963
# 149: Brecksville-Broadview Heights High School - 0.0157286265208194
# 150: Homeschool Science Colorado - 0.015539256045585162
# 151: Foothill High School - 0.015323400768144703
# 152: Los Alamitos High School - 0.01515077464444553
# 153: Eagan High School - 0.014762293243305902
# 154: Birmingham Groves High School - 0.014652014652014652
# 155: Glenbrook South High School - 0.014390371533228676
# 156: The College Preparatory School - 0.014373811842166274
# 157: Central High School - 0.014352119615277516
# 158: Stow-Munroe Falls High School - 0.01415576386873746
# 159: Slinger High School - 0.013985330441026645
# 160: Sheldon High School - 0.013791060691330232
# 161: Mount Vernon High School - 0.013596849039887017
# 162: John Hersey High School - 0.013490973312401884
# 163: Wilbraham and Moson Academy - 0.01329439790978253
# 164: Lakeville North High School - 0.013208367638747385
# 165: Irvine High School - 0.012819886237607757
# 166: Naper Valley Homeschool - 0.012591575091575092
# 167: Cambridge High School - 0.012431404836468131
# 168: Northview High School - 0.012397858551704707
# 169: Santa Teresa High School - 0.012366648253235994
# 170: Leigh High School - 0.01225872061451576
# 171: Gwinnett School of Mathematics, Science, and Technology - 0.0120429234353285
# 172: Evanston High School - 0.011692176870748298
# 173: Woodbury High School - 0.011654442034188871
# 174: Springfield High School - 0.011270780501549735
# 175: Delano High School - 0.01126596063304924
# 176: Fairview High School - 0.011010038564573584
# 177: National Cathedral School - 0.010877479231909612
# 178: Lyons Township High School - 0.010792778649921507
# 179: JR Masterman School - 0.010764089711458138
# 180: Sequoia High School - 0.01072638053770129
# 181: John Marshall High School - 0.010488997830769986
# 182: Perry High School - 0.01014370245139476
# 183: Silver Creek High School - 0.010100516429630354
# 184: Phillips Exeter Academy - 0.009970798432336902
# 185: Lisle High School - 0.009893380429094715
# 186: Amherst-Pelham Regional High School - 0.009712035028490726
# 187: Worthington Kilbourne High School - 0.009437175912491642
# 188: Evansville High School - 0.009323553627351095
# 189: Saratoga High School - 0.009194040460886819
# 190: Olentangy High School - 0.009016624401239787
# 191: Belvidere North High School - 0.008993982208267921
# 192: Crean Lutheran High School - 0.008935072226211467
# 193: Staples High School - 0.00854659082507184
# 194: Lincoln Science Focus Program High School - 0.008158109423932209
# 195: James B. Conant High School - 0.00809458398744113
# 196: Rocky River High School - 0.007889546351084815
# 197: Cleveland Heights High School - 0.0078643132604097
# 198: Saint Francis High School - 0.007661700384072354
# 199: Legacy High School - 0.0073811466216529495
# 200: Buffalo Grove High School - 0.007195185766614338
# 201: Parsippany High School - 0.007176059807638758
# 202: Potomac Falls High School - 0.006992665220513322
# 203: Ottawa Hills High School - 0.006762468300929842
# 204: Brookline High School - 0.006647198954891256
# 205: Alpharetta High School - 0.006604183819373694
# 206: Dundee-Crown High School - 0.006295787545787546
# 207: Columbus Academy - 0.006291450608327759
# 208: Kohler High School - 0.006215702418234064
# 209: Clayton Valley Charter High School - 0.0061293603072578836
# 210: Miller Place High School - 0.005827221017094436
# 211: Haslett High School - 0.005635390250774866
# 212: Sheboygan North High School - 0.005438739615954804
# 213: Loyola Academy - 0.005396389324960753
# 214: Minnetonka High School - 0.005050258214815177
# 215: Orange High School - 0.0047185879562458176
# 216: West Babylon Senior High School - 0.004661776813675549
# 217: Oak Harbor High School - 0.0045083122006198935
# 218: Harlem High School - 0.004496991104133961
# 219: Lake Braddock Secondary School - 0.0042732954125359185
# 220: West Bend High School - 0.0038848140113962905
# 221: Palatine High School - 0.003597592883307169
# 222: Kingsway Regional High School - 0.003588029903819379
# 223: Platteville High School - 0.003496332610256663
# 224: The Winsor School - 0.003323599477445628
# 225: Plainfield North High School - 0.003107851209117032
# 226: Peru - 0.0030646801536289418
# 227: La CaÃ±ada High School - 0.002719369807977404
# 228: Hinsdale South High School - 0.0026981946624803767
# 229: Cornerstone Charter Academy - 0.002330888406837773
# 230: West Liberty-Salem High School - 0.0022541561003099485
# 231: Westfield Area High School - 0.0019424070056981452
# 232: Prairie Ridge High School - 0.0017987964416535844
# 233: Athens Area High School - 0.0015728626520819416
# 234: Maclay School - 0.0015539256045585175
# 235: La Mirada High School - 0.0015323400768144709
# 236: Homestead High School - 0.0011654442034188864
# 237: Maumee Valley Country Day School - 0.0011270780501549723
# 238: Niles North High School - 0.0008993982208267922
# 239: Stratford Preparatory Academy - 0.0007769628022792587
# 240: STEAM HEAT Homeschooling Group - 0.0003884814011396277
# 241: Durand High School - 0.0
# 242: Mars Hill Academy - 0.0
# 243: Philadelphia High School for Girls - 0.0
# 244: Whitney M. Young Magnet High School - 0.0
# 245: Pilgrim High School - 0.0
# 246: Portola High School - 0.0
# 247: Wesleyan School - 0.0

# %% [markdown]
# This model's major flaw is it favors teams who attended the tournaments in which we sampled from. The weighing could be done on a non-linear regression and expanding the sample size of tournaments would be beneficial.
#
# Possible ideas to compensate:
# - When a team does not attend a tournament, assign them some sort of default score
